# %%
WILDFIRES_URL = (
    "https://github.com/astrojuanlu/ie-mbd-python-data-analysis-i/raw/main/"
    "data/fires-subset.csv"
)

# %%
import pandas as pd

# %%
df_wf = pd.read_csv(WILDFIRES_URL)
df_wf.head()

# %%
len(df_wf)

# %%
if len(df_wf) > 20_000:
  print("Large dataset")
else:
  print("Short dataset")

# %%
BIG_LANDLORDS_URL = (
    "https://github.com/astrojuanlu/ie-mbd-python-data-analysis-i/raw/main/"
    "data/grandes-tenedores-madrid.csv"
)

# %%
df_madrid = pd.read_csv(BIG_LANDLORDS_URL)
df_madrid.head()

# %%
# if (df_madrid["Matriz"] == "Aena").any():  # Wrong answer!
#   print("Yes")

# %%
df_aena = df_madrid.loc[df_madrid["Matriz"] == "Aena"]
df_aena

# %%
if len(df_aena) > 1:
  print("Yes")
else:
  print("no")

# %%
area_cutoff = df_wf["superficie"].quantile(0.99)
area_cutoff

# %%
num_rows_above_cutoff = len(df_wf.loc[df_wf["superficie"] > area_cutoff])

if num_rows_above_cutoff > 0:
  if num_rows_above_cutoff > 10:
    print("Cap at 99th percentile")
  else:
    print("Remove outliers individually")
else:
  print("No outliers detected")
