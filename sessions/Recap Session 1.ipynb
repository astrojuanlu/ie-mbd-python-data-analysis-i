# %%
import json

# %%
with open("data/rick-and-morty.json") as fh:
    data = json.load(fh)

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'id': 216,
#  'url': 'https://www.tvmaze.com/shows/216/rick-and-morty',
#  'name': 'Rick and Morty',
#  'type': 'Animation',
#  'language': 'English',
#  'genres': ['Comedy', 'Adventure', 'Science-Fiction'],
#  'status': 'Running',
#  'runtime': 30,
#  'averageRuntime': 30,
#  'premiered': '2013-12-02',
#  'ended': None,
#  'officialSite': 'http://www.adultswim.com/videos/rick-and-morty',
#  'schedule': {'time': '23:00', 'days': ['Sunday']},
#  'rating': {'average': 9},
#  'weight': 99,
#  'network': {'id': 10,
#   'name': 'Adult Swim',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'}},
#  'webChannel': None,
#  'dvdCountry': None,
#  'externals': {'tvrage': 33381, 'thetvdb': 275274, 'imdb': 'tt2861424'},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/1/3603.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/1/3603.jpg'},
# ...

# %%
data.keys()
# Out:
# dict_keys(['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime', 'averageRuntime', 'premiered', 'ended', 'officialSite', 'schedule', 'rating', 'weight', 'network', 'webChannel', 'dvdCountry', 'externals', 'image', 'summary', 'updated', '_links', '_embedded'])

# %%
# Documentation of the method:
data.keys?
# Out:
# Docstring: D.keys() -> a set-like object providing a view on D's keys
# Type:      builtin_function_or_method

# %%
data["id"]
# Out:
# 216

# %%
data["name"]
# Out:
# 'Rick and Morty'

# %% [markdown]
# ## Exercises
#
# Use a loop to print the type of every value in the dictionary

# %%
type(data["id"])
# Out:
# int

# %%
type(data["name"])
# Out:
# str

# %%
# All the keys are strings
# for key in data.keys():
#     print(type(key))

# %%
# No `return` statements outside
# for key in daya.keys():
#     return type(key)

# %%
# TypeError: string indices must be integers
# for key in data.keys():
#     print(type(key[key]))

# %%
# TypeError: list indices must be integers or slices, not str
# [1, 2, 3]["a"]

# %%
# By default, when you iterate over a dictionary,
# you iterate over the keys
# for key in data:
for key in data.keys():
    print(key, type(data[key]))
# Out:
# id <class 'int'>
# url <class 'str'>
# name <class 'str'>
# type <class 'str'>
# language <class 'str'>
# genres <class 'list'>
# status <class 'str'>
# runtime <class 'int'>
# averageRuntime <class 'int'>
# premiered <class 'str'>
# ended <class 'NoneType'>
# officialSite <class 'str'>
# schedule <class 'dict'>
# rating <class 'dict'>
# weight <class 'int'>
# network <class 'dict'>
# webChannel <class 'NoneType'>
# dvdCountry <class 'NoneType'>
# externals <class 'dict'>
# image <class 'dict'>
# summary <class 'str'>
# updated <class 'int'>
# _links <class 'dict'>
# _embedded <class 'dict'>

# %%
# for key, value in data.items():
#     print(key, type(value))

# %%
# print(type(key))  # "string indices must be integers"
# all str

# %%
len(data)
# Out:
# 24

# %%
len(data.keys())
# Out:
# 24

# %%
data["_embedded"].keys()
# Out:
# dict_keys(['episodes'])

# %%
episodes = data["_embedded"]["episodes"]

# %%
type(episodes)
# Out:
# list

# %%
len(episodes)
# Out:
# 51

# %%
episodes[0]
# Out:
# {'id': 14308,
#  'url': 'https://www.tvmaze.com/episodes/14308/rick-and-morty-1x01-pilot',
#  'name': 'Pilot',
#  'season': 1,
#  'number': 1,
#  'type': 'regular',
#  'airdate': '2013-12-02',
#  'airtime': '22:30',
#  'airstamp': '2013-12-03T03:30:00+00:00',
#  'runtime': 30,
#  'rating': {'average': 8.6},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/292/730352.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/292/730352.jpg'},
#  'summary': "<p>Rick takes Morty to another dimension to get some seeds for him but Morty's parents are considering to put Rick in a retirement home for keeping Morty away from school to help him in his lab.</p>",
#  '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/14308'}}}

# %% [markdown]
# ### Exercise 2
#
# Use a `for` loop to print the airdate of every episode *and* the episode season.

# %%
air = data["_embedded"]["episodes"]

for element in air:
    ...

# %%
list_of_episodes = data["_embedded"]["episodes"]

for episode in list_of_episodes:
    ...

# %% [markdown]
# ---

# %%
# As a rule of thumb,
# you don't need `list_of_episodes`
# if you already do:
for episode in list_of_episodes:
    print(episode["season"], episode["airdate"])
# Out:
# 1 2013-12-02
# 1 2013-12-09
# 1 2013-12-16
# 1 2014-01-13
# 1 2014-01-20
# 1 2014-01-27
# 1 2014-03-10
# 1 2014-03-17
# 1 2014-03-24
# 1 2014-04-07
# 1 2014-04-14
# 2 2015-07-26
# 2 2015-08-02
# 2 2015-08-09
# 2 2015-08-16
# 2 2015-08-23
# 2 2015-08-30
# 2 2015-09-13
# 2 2015-09-20
# 2 2015-09-27
# 2 2015-10-04
# 3 2017-04-01
# 3 2017-07-30
# 3 2017-08-06
# 3 2017-08-13
# 3 2017-08-20
# 3 2017-08-27
# 3 2017-09-10
# 3 2017-09-17
# 3 2017-09-24
# 3 2017-10-01
# 4 2019-11-10
# 4 2019-11-17
# 4 2019-11-24
# 4 2019-12-08
# 4 2019-12-15
# 4 2020-05-03
# 4 2020-05-10
# 4 2020-05-17
# 4 2020-05-24
# 4 2020-05-31
# 5 2021-06-20
# 5 2021-06-27
# 5 2021-07-04
# 5 2021-07-11
# 5 2021-07-18
# 5 2021-07-25
# 5 2021-08-01
# 5 2021-08-08
# 5 2021-09-05
# 5 2021-09-05

# %%
# At the end of a loop,
# `episode` is the last element of `list_of_episodes`
episode["airdate"]
# Out:
# '2021-09-05'

# %%
list_of_episodes[-1]["airdate"]
# Out:
# '2021-09-05'

# %% [markdown]
# What is the year of the last episode?
